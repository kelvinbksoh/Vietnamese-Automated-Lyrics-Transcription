# %%
from pathlib import Path
from pydub import AudioSegment
from pydub.playback import play
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
path = 'audio_processing/demucs/htdemucs_preprocessed_100'
extensions = ["mp3"]

audio_filenames = []
for file in Path(path).iterdir():
    if file.suffix.lower().lstrip(".") in extensions:
        audio_filenames.append(str(file))

# %%
audio_filenames
# Out:
# ['audio_processing/demucs/htdemucs_preprocessed_100/Tình Online Không Có Ngày Mai.mp3',
#  'audio_processing/demucs/htdemucs_preprocessed_100/Áo Dài Việt Nam.mp3',
#  'audio_processing/demucs/htdemucs_preprocessed_100/Canh Bạc Cuộc Đời.mp3',
#  'audio_processing/demucs/htdemucs_preprocessed_100/Ước Muốn Của Em (Acoustic Version).mp3',
#  'audio_processing/demucs/htdemucs_preprocessed_100/Bước Chân Con Trở Về.mp3',
#  'audio_processing/demucs/htdemucs_preprocessed_100/Thương Em Miền Nước Lũ.mp3',
#  'audio_processing/demucs/htdemucs_preprocessed_100/Mưa Nước Mắt.mp3',
#  'audio_processing/demucs/htdemucs_preprocessed_100/Con Tim Em Đã Đổi Thay.mp3',
#  'audio_processing/demucs/htdemucs_preprocessed_100/Búp bê bị hư.mp3',
#  'audio_processing/demucs/htdemucs_preprocessed_100/Cuộc Tình Trong Mơ.mp3',
#  'audio_processing/demucs/htdemucs_preprocessed_100/Ba Đứa Bạn Nghèo.mp3',
#  'audio_processing/demucs/htdemucs_preprocessed_100/Hôm Nay Anh Đang Làm Gì？ (Beat).mp3',
#  'audio_processing/demucs/htdemucs_preprocessed_100/Bình Minh Mùa Thu.mp3',
#  'audio_processing/demucs/htdemucs_preprocessed_100/Chúng Ta Là Tri Kỉ.mp3',
#  'audio_processing/demucs/htdemucs_preprocessed_100/Em LÀ Ánh Dương.mp3',
#  'audio_processing/demucs/htdemucs_preprocessed_100/Cho Anh Quay Lại Nơi Bắt Đầu.mp3',
#  'audio_processing/demucs/htdemucs_preprocessed_100/Tình Yêu Không Thể Từ Một Phía.mp3',
#  'audio_processing/demucs/htdemucs_preprocessed_100/Em Mong Chờ Anh.mp3',
#  'audio_processing/demucs/htdemucs_preprocessed_100/Xin Em Thôi Làm Ngơ.mp3',
#  'audio_processing/demucs/htdemucs_preprocessed_100/Lk Phải Lòng Con Gái Bến Tre Áo Mới Cà Mau.mp3',
#  'audio_processing/demucs/htdemucs_preprocessed_100/Liên Khúc Con Đường Xưa Em Đi.mp3',
#  'audio_processing/demucs/htdemucs_preprocessed_100/4 Phút 20 Giây (Về Nhà Với Anh Đi).mp3',
#  'audio_processing/demucs/htdemucs_preprocessed_100/AY DA.mp3',
#  'audio_processing/demucs/htdemucs_preprocessed_100/Bờm Có Quạt Mo.mp3',
#  'audio_processing/demucs/htdemucs_preprocessed_100/Anh Không Làm Được.mp3',
#  'audio_processing/demucs/htdemucs_preprocessed_100/Có Phải Anh Là (Beat).mp3',
#  'audio_processing/demucs/htdemucs_preprocessed_100/Em Thuộc Về Ai.mp3',
#  'audio_processing/demucs/htdemucs_preprocessed_100/Đồng Tiền Rẽ Lối (Parody).mp3',
#  'audio_processing/demucs/htdemucs_preprocessed_100/Biết Yêu Thật Nhiều.mp3',
#  'audio_processing/demucs/htdemucs_preprocessed_100/Tôi Xa Người Yêu.mp3',
#  'audio_processing/demucs/htdemucs_preprocessed_100/Chúng Ta Không Thể Yêu Thêm Lần Nữa (Prod. Vic).mp3',
#  'audio_processing/demucs/htdemucs_preprocessed_100/Liên Khúc 13 Tỉnh Thành.mp3',
#  'audio_processing/demucs/htdemucs_preprocessed_100/Ba Mẹ Đi Xa.mp3',
#  'audio_processing/demucs/htdemucs_preprocessed_100/Anh Biết Không Anh.mp3',
#  'audio_processing/demucs/htdemucs_preprocessed_100/Mùa Đông Tuyệt Vọng.mp3',
#  'audio_processing/demucs/htdemucs_preprocessed_100/Giết Người Trong Mộng.mp3',
#  'audio_processing/demucs/htdemucs_preprocessed_100/Từ Nay Không Phiền Anh Nữa (Remix).mp3',
#  'audio_processing/demucs/htdemucs_preprocessed_100/Em Mang Tình Mình Trao Ai.mp3',
#  'audio_processing/demucs/htdemucs_preprocessed_100/Bánh Trung Thu.mp3',
#  'audio_processing/demucs/htdemucs_preprocessed_100/Liên Khúc Đón Xuân.mp3',
#  'audio_processing/demucs/htdemucs_preprocessed_100/Em Rất Cô Đơn.mp3',
#  'audio_processing/demucs/htdemucs_preprocessed_100/Bạn Hay Bè.mp3',
#  'audio_processing/demucs/htdemucs_preprocessed_100/Càng Trưởng Thành Càng Cô Đơn ⧸ Gửi Người Yêu Cũ (Live).mp3',
#  'audio_processing/demucs/htdemucs_preprocessed_100/Ừ Thì Anh Sai.mp3',
#  'audio_processing/demucs/htdemucs_preprocessed_100/Huyến Thoại Rượu.mp3',
#  'audio_processing/demucs/htdemucs_preprocessed_100/Bé Đi Học.mp3',
#  'audio_processing/demucs/htdemucs_preprocessed_100/Đừng Nhìn Lên Em Ơi.mp3',
#  'audio_processing/demucs/htdemucs_preprocessed_100/Tự Thân Nàng Cứu Độ Nàng.mp3',
#  'audio_processing/demucs/htdemucs_preprocessed_100/Đâu Ai Vì Nhau.mp3',
#  'audio_processing/demucs/htdemucs_preprocessed_100/Cảm Giác Em Là Sao (Remix).mp3',
#  'audio_processing/demucs/htdemucs_preprocessed_100/Bước Tiến Bước.mp3',
#  'audio_processing/demucs/htdemucs_preprocessed_100/Cả Một Đời Để Quên (Meme Lofi).mp3',
#  'audio_processing/demucs/htdemucs_preprocessed_100/Đành Để Em Đi.mp3',
#  'audio_processing/demucs/htdemucs_preprocessed_100/Con Bướm Xuân (Beat).mp3',
#  'audio_processing/demucs/htdemucs_preprocessed_100/Mãi Mãi Bên Em.mp3',
#  'audio_processing/demucs/htdemucs_preprocessed_100/Dù Một Mai.mp3',
#  'audio_processing/demucs/htdemucs_preprocessed_100/Khói Thuốc Đợi Chờ.mp3',
#  'audio_processing/demucs/htdemucs_preprocessed_100/Tết Đến Rồi Sao Chẳng Thấy Em Đâu.mp3',
#  'audio_processing/demucs/htdemucs_preprocessed_100/Chỉ Mong Em Bình An.mp3',
#  'audio_processing/demucs/htdemucs_preprocessed_100/Bất Nhiễm (Cover).mp3',
#  'audio_processing/demucs/htdemucs_preprocessed_100/Bên Em.mp3',
#  'audio_processing/demucs/htdemucs_preprocessed_100/Chạm Vào Hơi Thở.mp3',
#  'audio_processing/demucs/htdemucs_preprocessed_100/Để Anh Được Yêu.mp3',
#  'audio_processing/demucs/htdemucs_preprocessed_100/Tình Si.mp3',
#  'audio_processing/demucs/htdemucs_preprocessed_100/Người Không Cần Yêu.mp3',
#  'audio_processing/demucs/htdemucs_preprocessed_100/Anh Nói Yêu Em Được Không (Awriix Remix).mp3',
#  'audio_processing/demucs/htdemucs_preprocessed_100/Mùa Xuân Em Hát.mp3',
#  'audio_processing/demucs/htdemucs_preprocessed_100/Lệ Đắng Tình Yêu.mp3',
#  'audio_processing/demucs/htdemucs_preprocessed_100/Tình Buồn Đêm Mưa.mp3',
#  'audio_processing/demucs/htdemucs_preprocessed_100/Kết Thúc Như Vậy Sao.mp3',
#  'audio_processing/demucs/htdemucs_preprocessed_100/Bé Mắt Nhung.mp3',
#  'audio_processing/demucs/htdemucs_preprocessed_100/Đáng Thương.mp3',
#  'audio_processing/demucs/htdemucs_preprocessed_100/Anh, Em Và Đêm.mp3',
#  'audio_processing/demucs/htdemucs_preprocessed_100/Cào Cào Bay Trong Gió.mp3',
#  'audio_processing/demucs/htdemucs_preprocessed_100/Đừng Xa Em Người Ơi.mp3',
#  'audio_processing/demucs/htdemucs_preprocessed_100/Nói Với Anh Đôi Lời.mp3',
#  'audio_processing/demucs/htdemucs_preprocessed_100/Bỉ Ngạn.mp3',
#  'audio_processing/demucs/htdemucs_preprocessed_100/Anh Em MaCau (SinKra remix).mp3',
#  'audio_processing/demucs/htdemucs_preprocessed_100/Chuyện Tình Gió.mp3',
#  'audio_processing/demucs/htdemucs_preprocessed_100/Có Chó Nó Yêu Mày.mp3',
#  'audio_processing/demucs/htdemucs_preprocessed_100/Biết Nói Thế Nào.mp3',
#  'audio_processing/demucs/htdemucs_preprocessed_100/Tình Ca Mùa Xuân.mp3',
#  'audio_processing/demucs/htdemucs_preprocessed_100/Khói Sương.mp3',
#  'audio_processing/demucs/htdemucs_preprocessed_100/Chuỗi Ngày Vắng Em.mp3',
#  'audio_processing/demucs/htdemucs_preprocessed_100/Chờ Ngày Cưới Em.mp3',
#  'audio_processing/demucs/htdemucs_preprocessed_100/Bỏ Lại.mp3',
#  'audio_processing/demucs/htdemucs_preprocessed_100/365 Ngày Yêu (Remix).mp3',
#  'audio_processing/demucs/htdemucs_preprocessed_100/Tổ Quốc Nhìn Từ Biển.mp3',
#  'audio_processing/demucs/htdemucs_preprocessed_100/Dân Ca DJ 2.mp3',
#  'audio_processing/demucs/htdemucs_preprocessed_100/Chợt Nhận Ra.mp3',
#  'audio_processing/demucs/htdemucs_preprocessed_100/Bạc Lòng.mp3',
#  'audio_processing/demucs/htdemucs_preprocessed_100/Bài Toán Tình Yêu.mp3',
#  'audio_processing/demucs/htdemucs_preprocessed_100/Một Lần Về Với Biển.mp3',
#  'audio_processing/demucs/htdemucs_preprocessed_100/Rap Về Doraemon.mp3',
#  'audio_processing/demucs/htdemucs_preprocessed_100/Hận Mình Tay Trắng (Yang Remix).mp3',
#  'audio_processing/demucs/htdemucs_preprocessed_100/Phút Giây Muộn Màng.mp3',
#  'audio_processing/demucs/htdemucs_preprocessed_100/Là Vì Ai (Another Version).mp3',
#  'audio_processing/demucs/htdemucs_preprocessed_100/Cả Một Đời Người Xin Mượn Một Đoạn Đường.mp3',
#  'audio_processing/demucs/htdemucs_preprocessed_100/Màu Hoa Kỷ Niệm.mp3',
#  'audio_processing/demucs/htdemucs_preprocessed_100/Hỷ Nộ Ái Ố Kiếp Người.mp3']

# %%
sound = AudioSegment.from_file(audio_filenames[0], format="mp3")
sound1 = AudioSegment.from_file(audio_filenames[1], format="mp3")
# play(sound)

# %%
def plot_dbfs(audio_segment, time_window=1000) -> None:
    d = {'time': [], 'dbfs': []}
    for i, chunk in enumerate(audio_segment[::time_window]):
        d['time'].append(time_window*i/1000)
        d['dbfs'].append(chunk.dBFS)
    df = pd.DataFrame(data=d)
    sns.lineplot(data=df, x="time", y="dbfs")
    # plot average dbfs
    plot_df = df.replace(-np.inf, np.nan)
    plt.axhline(y = plot_df.loc[:, 'dbfs'].dropna().mean(), color = 'r', linestyle = '-') 
    print('Mean dbFS: ', plot_df.loc[:, 'dbfs'].dropna().mean())
    plt.show()

plot_dbfs(sound, time_window=1000)
# Out:
# Mean dbFS:  -32.957633789017024

# %%
def suppress_silence(audio:AudioSegment, time_window=1000, ignore_duration_multiple=2) -> AudioSegment:
    d = {'time': [], 'dbfs': []}
    for i, chunk in enumerate(audio[::time_window]):
        d['time'].append(time_window*i/1000)
        d['dbfs'].append(chunk.dBFS)
    df = pd.DataFrame(data=d)

    plot_df = df.copy(deep=True).replace(-np.inf, np.nan)
    mean_dbfs = plot_df.loc[:, 'dbfs'].dropna().mean()

    ignore_duration = int((time_window/1000)*ignore_duration_multiple)
    df['dbfs_prev'] = df['dbfs'].shift(periods=ignore_duration)
    df['dbfs_after'] = df['dbfs'].shift(periods=-ignore_duration)
    df['silence'] = df.apply(lambda x: True if ((x['dbfs'] < mean_dbfs) & ((x['dbfs_prev'] < mean_dbfs) | (x['dbfs_prev']== np.nan)) & (x['dbfs_after'] < mean_dbfs) | (x['dbfs'] == -np.inf)) else False, axis=1)
    # silence_df = df.loc[(df['dbfs'] < mean_dbfs) & (df['dbfs_prev'] < mean_dbfs) & (df['dbfs_after'] < mean_dbfs)]
    # print(df.iloc[136:140,:])
    prev_time = None
    prev_action = None
    curr_time = None
    curr_action = None
    cache = {}
    for idx, row in enumerate(df.itertuples()):
        # sample of row: Index=0, time=0.0, dbfs=-84.28839878591472, dbfs_prev=nan, dbfs_after=-80.76657360480111, silence=False
        if prev_time == None:
            # print('test: ', row)
            prev_time = row[1]
            prev_action = row[5]

        curr_time = row[1]
        curr_action = row[5]
        if prev_action != curr_action:
            # print(row)
            cache[idx] = {'action':prev_action, 'start':int(prev_time*1000), 'stop': int(curr_time*1000)}
            prev_time = curr_time
            prev_action = curr_action
        
        if idx == len(df)-1:
            cache[idx] = {'action':prev_action, 'start':int(prev_time*1000), 'stop': int(curr_time*1000)}
    print(cache)
    output = AudioSegment.empty()
    for _, v in cache.items():
        if v['action']: # True -> apply silence
            duration = v['stop'] - v['start']
            output += AudioSegment.silent(duration=duration)
        else: # False -> append original audio
            output += audio[v['start']:v['stop']]
    return output
    pass

suppress_audio = suppress_silence(sound, time_window=1000, ignore_duration_multiple=2)
# Out:
# {32: {'action': True, 'start': 0, 'stop': 32000}, 101: {'action': False, 'start': 32000, 'stop': 101000}, 129: {'action': True, 'start': 101000, 'stop': 129000}, 226: {'action': False, 'start': 129000, 'stop': 226000}}

# %%
len(suppress_audio)
# Out:
# 226000

# %%
len(sound)
# Out:
# 226247

# %%
plot_dbfs(suppress_audio, time_window=1000)
# Out:
# Mean dbFS:  -18.579979224440457

# %% [markdown]
# ### Play the audio

# %%
play(suppress_audio)

# %% [markdown]
# ### Export Audio

# %%
# simple export
file_handle = suppress_audio.export("output.mp3", format="mp3")
